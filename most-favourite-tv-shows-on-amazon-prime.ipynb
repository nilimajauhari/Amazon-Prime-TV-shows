# %% [markdown]
# **Let us explore the data set and identify the high rated shows on Amazon Prime**

# %% [markdown]
# Let us start by importing the required libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/amazon-prime-tv-shows/Prime TV Shows Data set.csv

# %%
# Reading the data set
tv_shows = pd.read_csv("/kaggle/input/amazon-prime-tv-shows/Prime TV Shows Data set.csv",encoding="iso-8859-1")

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# Let us look at the shape of the data
tv_shows.shape
# Out:
# (503, 8)

# %% [markdown]
# So we can see that there are 503 rows and 8 columns or attributes in the data set, which means there are 503 TV shows of different categories or genres available on Prime.

# %%
# Visualizing the first few rows of the data set
tv_shows.head(3)
# Out:
#    S.no.           Name of the show  Year of release  No of seasons available  \
# 0      1                 Pataal Lok             2020                        1
# 1      2                     Upload             2020                        1
# 2      3  The Marvelous Mrs. Maisel             2017                        3
#
#   Language          Genre  IMDb rating Age of viewers
# 0    Hindi          Drama          7.5            18+
# 1  English  Sci-fi comedy          8.1            16+
# 2  English  Drama, Comedy          8.7            16+

# %%
# Let us take a look at the data types of each variable
tv_shows.dtypes
# Out:
# S.no.                        int64
# Name of the show            object
# Year of release              int64
# No of seasons available      int64
# Language                    object
# Genre                       object
# IMDb rating                float64
# Age of viewers              object
# dtype: object

# %%
# Looking at the age of viewers
import seaborn as sns
sns.set(style="darkgrid")
ax = sns.countplot(x = "Age of viewers", data = tv_shows)

# %% [markdown]
# Here we can see that most of the shows are either 16+ (adult shows) or are for all age groups.

# %%
# Let us take a look at the languages in which TV shows are being offered
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(7, 3))
sns.countplot(y = "Language", data = tv_shows)

# %% [markdown]
# Here we can see that most of the shows are having audio language as 'English', while he second audio language is 'Hindi'. This means that most of the shows on Amazon Prime are either Hindi or English while TV shows in other languages such as Japanese, Italian, Spanish are very less.

# %%
# Let us take a look at the genres of the TV shows
f, ax = plt.subplots(figsize=(7, 10))
sns.countplot(y = "Genre", data = tv_shows)

# %% [markdown]
# We can see that most of the shows available are of the genre: 'drama', 'comedy' or are for 'kids'.

# %%
# Let us take a look at how many seasons of the show are available on Prime
f, ax = plt.subplots(figsize=(7, 10))
sns.countplot(y = "No of seasons available", data = tv_shows)

# %% [markdown]
# We can see here that only season 1 is available for most of the TV shows. While for some TV shows all the seasons are available on Prime, upto 9 or 10 seasons.

# %%
# Let us now check for missing values
tv_shows.isnull().sum()
# Out:
# S.no.                        0
# Name of the show             0
# Year of release              0
# No of seasons available      0
# Language                     0
# Genre                        0
# IMDb rating                283
# Age of viewers               0
# dtype: int64

# %% [markdown]
# We can see that the variable IMDb ratings has the most missing values while there are no other missing values in any column.

# %% [markdown]
# We can fill or replace the missing values. In some cases, we can delete the rows with missing values and in some cases we can replace the missing values.But dropping rows or columns with missing values can lead to loss of information and precision. So we need to handle these missing values or replace them.

# %%
# Checking for outliers
sns.boxplot(x ='Age of viewers',y = 'IMDb rating',data = tv_shows,palette ='rainbow')

# %% [markdown]
# Since there are many outliers we will replace the missing value with the median value for the IMDb rating.

# %%
# Replace using median 
median = tv_shows['IMDb rating'].median()
tv_shows['IMDb rating'].fillna(median, inplace=True)

# %% [markdown]
# Let us now check whether the missing values have been replaced or not.

# %%
tv_shows.isnull().sum()
# Out:
# S.no.                      0
# Name of the show           0
# Year of release            0
# No of seasons available    0
# Language                   0
# Genre                      0
# IMDb rating                0
# Age of viewers             0
# dtype: int64

# %% [markdown]
# Now we can see that we don't have any missing values.

# %%
# Let us take a look at the top 20 high rated shows on Amazon Prime
tv_shows.sort_values(by = "IMDb rating", ascending = False).head(20)
# Out:
#      S.no.                          Name of the show  Year of release  \
# 20      21  The Test: A New Era for Australia's Team             2020
# 281    282                                  Seinfeld             1990
# 49      50                            Downtown Abbey             2010
# 2        3                 The Marvelous Mrs. Maisel             2017
# 37      38                               Hostel Daze             2019
# 4        5                                   Fleabag             2016
# 340    341                            The Grand Tour             2017
# 51      52                                This is Us             2017
# 12      13                                  The Boys             2019
# 40      41                                    Dexter             2006
# 47      48                                 Shameless             2011
# 8        9                            The Family Man             2019
# 105    106                                   Mad Men             2007
# 436    437                               Tumble Leaf             2014
# 28      29                                     Suits             2011
# 38      39                                 Mr. Robot             2015
# 85      86                       The Handmaid's Tale             2017
# 261    262                                  Mr. Bean             1995
# 7        8                                  Mirzapur             2018
# 16      17                                   Breathe             2018
#
#      No of seasons available Language            Genre  IMDb rating  \
# 20                         1  English      Documentary          9.0
# 281                        9  English           Comedy          8.8
# 49                         6  English            Drama          8.7
# 2                          3  English    Drama, Comedy          8.7
# 37                         1    Hindi    Drama, Comedy          8.7
# 4                          2  English           Comedy          8.7
# 340                        4  English           Sports          8.7
# 51                         3  English            Drama          8.7
# 12                         1  English   Action, Comedy          8.7
# 40                         8  English            Drama          8.6
# 47                        10  English    Comedy, Drama          8.6
# 8                          1    Hindi    Drama, Action          8.6
# 105                        7  English            Drama          8.6
# 436                        6  English             Kids          8.6
# 28                         8  English            Drama          8.5
# 38                         3  English  Drama, Suspense          8.5
# 85                         3  English            Drama          8.5
# 261                        1  English           Comedy          8.5
# 7                          1    Hindi            Drama          8.5
# 16                         1    Hindi  Drama, Suspense          8.4
#
#     Age of viewers
# 20             16+
# 281            13+
# 49              7+
# 2              16+
# 37             16+
# 4              18+
# 340            16+
# 51             16+
# 12             18+
# 40             18+
# 47             18+
# 8              18+
# 105            16+
# 436            All
# 28             16+
# 38             18+
# 85             18+
# 261            16+
# 7              18+
# 16             16+

# %%
# Let us now take a look at 20 worst rated shows
tv_shows.sort_values(by = "IMDb rating", ascending = True).head(20)
# Out:
#      S.no.                                Name of the show  Year of release  \
# 367    368             Ilana Glazer: The Planet is Burning             2020
# 162    163                                     Tokyo Alice             2019
# 243    244                                Skulls and Roses             2019
# 428    429                                  L.O.L Surprise             2019
# 413    414                                      Wishenpoof             2015
# 375    376                           Businessmen VS Aliens             2018
# 430    431                         Alvin and the Chipmunks             2017
# 317    318  Alice Wettlund: My Mama is a Human and So Am I             2019
# 466    467                            Strawberry Shortcake             2003
# 473    474                              G.I. Joe Sigma Six             2006
# 175    176                                      Final Life             2019
# 3        4                          Four More Shots Please             2019
# 355    356                                #IMomSoHard Live             2019
# 341    342          The Adventures of Rocky and Bullwinkle             2018
# 352    353                Alonzo Bodden: Heavy Lightweight             2019
# 418    419                                Ben 10 Omniverse             2013
# 447    448                                     Bug Diaries             2020
# 283    284                                    Chaplin & Co             2012
# 427    428                     The Dangerous Book for Boys             2018
# 331    332                                    SNG: What if             2016
#
#      No of seasons available  Language          Genre  IMDb rating  \
# 367                        1   English         Comedy          3.7
# 162                        1  Japanese          Drama          4.0
# 243                        1     Hindi         Action          4.3
# 428                        1   English           Kids          4.3
# 413                        4   English           Kids          4.4
# 375                        1  Japanese         Comedy          4.5
# 430                        4   English           Kids          4.5
# 317                        1   English         Comedy          4.7
# 466                        1   English           Kids          4.8
# 473                        1   English           Kids          4.9
# 175                        1  Japanese          Drama          5.2
# 3                          2     Hindi  Drama, Comedy          5.3
# 355                        1   English         Comedy          5.4
# 341                        2   English           Kids          5.4
# 352                        1   English         Comedy          5.6
# 418                        2   English           Kids          5.7
# 447                        2   English           Kids          5.7
# 283                        1   English         Comedy          5.8
# 427                        1   English           Kids          5.9
# 331                        1     Hindi         Comedy          6.0
#
#     Age of viewers
# 367            18+
# 162            13+
# 243            18+
# 428            All
# 413            All
# 375            13+
# 430             7+
# 317            16+
# 466            All
# 473             7+
# 175            16+
# 3              18+
# 355            16+
# 341            All
# 352            16+
# 418             7+
# 447            All
# 283             7+
# 427            All
# 331            All

# %% [markdown]
# **Let us now look at the top rated TV shows across different languages, genres as well as age categories**

# %%
top_english = tv_shows[tv_shows['Language'] == 'English'].sort_values(by = 'IMDb rating',ascending = False)
#Top 10 TV shows in english
top_english.head(10)
# Out:
#      S.no.                          Name of the show  Year of release  \
# 20      21  The Test: A New Era for Australia's Team             2020
# 281    282                                  Seinfeld             1990
# 4        5                                   Fleabag             2016
# 51      52                                This is Us             2017
# 49      50                            Downtown Abbey             2010
# 2        3                 The Marvelous Mrs. Maisel             2017
# 340    341                            The Grand Tour             2017
# 12      13                                  The Boys             2019
# 105    106                                   Mad Men             2007
# 436    437                               Tumble Leaf             2014
#
#      No of seasons available Language           Genre  IMDb rating  \
# 20                         1  English     Documentary          9.0
# 281                        9  English          Comedy          8.8
# 4                          2  English          Comedy          8.7
# 51                         3  English           Drama          8.7
# 49                         6  English           Drama          8.7
# 2                          3  English   Drama, Comedy          8.7
# 340                        4  English          Sports          8.7
# 12                         1  English  Action, Comedy          8.7
# 105                        7  English           Drama          8.6
# 436                        6  English            Kids          8.6
#
#     Age of viewers
# 20             16+
# 281            13+
# 4              18+
# 51             16+
# 49              7+
# 2              16+
# 340            16+
# 12             18+
# 105            16+
# 436            All

# %%
# Top 10 TV shows in Hindi
top_hindi = tv_shows[tv_shows['Language'] == 'Hindi'].sort_values(by = 'IMDb rating',ascending = False)
#Top 10 TV shows in hindi
top_hindi.head(10)
# Out:
#      S.no.                    Name of the show  Year of release  \
# 37      38                         Hostel Daze             2019
# 8        9                      The Family Man             2019
# 7        8                            Mirzapur             2018
# 16      17                             Breathe             2018
# 5        6                      Made in Heaven             2019
# 299    300                         Best of AIB             2014
# 11      12                         Inside Edge             2017
# 17      18  The Forgotten Army- Azaadi ke Liye             2020
# 83      84                  Bang Baaja Baaraat             2015
# 0        1                          Pataal Lok             2020
#
#      No of seasons available Language            Genre  IMDb rating  \
# 37                         1    Hindi    Drama, Comedy          8.7
# 8                          1    Hindi    Drama, Action          8.6
# 7                          1    Hindi            Drama          8.5
# 16                         1    Hindi  Drama, Suspense          8.4
# 5                          1    Hindi            Drama          8.3
# 299                        1    Hindi           Comedy          8.2
# 11                         2    Hindi    Sports, Drama          8.0
# 17                         1    Hindi    Drama, Action          8.0
# 83                         1    Hindi            Drama          8.0
# 0                          1    Hindi            Drama          7.5
#
#     Age of viewers
# 37             16+
# 8              18+
# 7              18+
# 16             16+
# 5              18+
# 299            16+
# 11             18+
# 17             18+
# 83             18+
# 0              18+

# %% [markdown]
# **Since most of the shows are of the genres: 'Drama', 'Comedy' and 'Kids'. Let us look at the top rated shows in each of these genres**

# %%
# Top 10 TV shows in the genre: 'Drama'
top_drama = tv_shows[tv_shows['Genre'] == 'Drama'].sort_values(by = 'IMDb rating',ascending = False)
#Top 10 TV shows in drama
top_drama.head(10)
# Out:
#      S.no.     Name of the show  Year of release  No of seasons available  \
# 51      52           This is Us             2017                        3
# 49      50       Downtown Abbey             2010                        6
# 105    106              Mad Men             2007                        7
# 40      41               Dexter             2006                        8
# 85      86  The Handmaid's Tale             2017                        3
# 7        8             Mirzapur             2018                        1
# 28      29                Suits             2011                        8
# 76      77                Bosch             2015                        6
# 142    143          Ray Donovan             2013                        6
# 154    155                 Life             2007                        2
#
#     Language  Genre  IMDb rating Age of viewers
# 51   English  Drama          8.7            16+
# 49   English  Drama          8.7             7+
# 105  English  Drama          8.6            16+
# 40   English  Drama          8.6            18+
# 85   English  Drama          8.5            18+
# 7      Hindi  Drama          8.5            18+
# 28   English  Drama          8.5            16+
# 76   English  Drama          8.4            18+
# 142  English  Drama          8.3            All
# 154  English  Drama          8.3            All

# %%
# Top 10 TV shows in the genre: 'Comedy'
top_comedy = tv_shows[tv_shows['Genre'] == 'Comedy'].sort_values(by = 'IMDb rating',ascending = False)
#Top 10 TV shows in comedy
top_comedy.head(10)
# Out:
#      S.no.                       Name of the show  Year of release  \
# 281    282                               Seinfeld             1990
# 4        5                                Fleabag             2016
# 261    262                               Mr. Bean             1995
# 293    294                        Californication             2007
# 299    300                            Best of AIB             2014
# 330    331                       EIC vs The World             2017
# 312    313                        Trial and Error             2017
# 374    375  Hitoshi Matsumoto Presents Documental             2018
# 315    316                               Red Oaks             2015
# 347    348                        People of Earth             2016
#
#      No of seasons available  Language   Genre  IMDb rating Age of viewers
# 281                        9   English  Comedy          8.8            13+
# 4                          2   English  Comedy          8.7            18+
# 261                        1   English  Comedy          8.5            16+
# 293                        7   English  Comedy          8.3            18+
# 299                        1     Hindi  Comedy          8.2            16+
# 330                        1   English  Comedy          8.0            16+
# 312                        2   English  Comedy          8.0            13+
# 374                        3  Japanese  Comedy          8.0            18+
# 315                        3   English  Comedy          7.9            18+
# 347                        2   English  Comedy          7.7            All

# %%
# Top 10 TV shows in the genre: 'Kids'
top_kids = tv_shows[tv_shows['Genre'] == 'Kids'].sort_values(by = 'IMDb rating',ascending = False)
#Top 10 TV shows for kids
top_kids.head(10)
# Out:
#      S.no.                         Name of the show  Year of release  \
# 436    437                              Tumble Leaf             2014
# 296    297                          Munki and Trunk             2016
# 452    453                          Jessy and Nessy             2020
# 411    412  Gortimer Gibbon's Life on Normal Street             2015
# 405    406                           Just Add Magic             2016
# 437    438                  Wolverine and the X-men             2016
# 421    422                      Dexter's Laboratory             1997
# 423    424                       Transformers Prime             2012
# 226    227                               Lost in Oz             2017
# 450    451              Niko and The Sword of Light             2017
#
#      No of seasons available Language Genre  IMDb rating Age of viewers
# 436                        6  English  Kids          8.6            All
# 296                        1  English  Kids          8.4            All
# 452                        1  English  Kids          8.3            All
# 411                        3  English  Kids          8.2            All
# 405                        5  English  Kids          8.2            All
# 437                        1  English  Kids          8.0             7+
# 421                        5  English  Kids          7.9            All
# 423                        3  English  Kids          7.8             7+
# 226                        2  English  Kids          7.7             7+
# 450                        3  English  Kids          7.7            All

# %%
# Let us now look at the top 10 best shows released this year which are a must watch
top10 = tv_shows[tv_shows['Year of release'] == 2020].sort_values(by ='IMDb rating',ascending = False)
#Top 10 TV shows of 2020
top10.head(10)
# Out:
#      S.no.                          Name of the show  Year of release  \
# 20      21  The Test: A New Era for Australia's Team             2020
# 452    453                           Jessy and Nessy             2020
# 1        2                                    Upload             2020
# 17      18        The Forgotten Army- Azaadi ke Liye             2020
# 73      74                         Star Trek: Picard             2020
# 0        1                                Pataal Lok             2020
# 19      20                       Tales from the Loop             2020
# 493    494                  Learning with Anima Cars             2020
# 492    493    Shark Academy: Nursery Rhymes for Kids             2020
# 339    340             Zoe Coombs Marr: Bossy Bottom             2020
#
#      No of seasons available Language          Genre  IMDb rating  \
# 20                         1  English    Documentary          9.0
# 452                        1  English           Kids          8.3
# 1                          1  English  Sci-fi comedy          8.1
# 17                         1    Hindi  Drama, Action          8.0
# 73                         1  English         Sci-fi          7.6
# 0                          1    Hindi          Drama          7.5
# 19                         1  English        Sci-fi           7.5
# 493                        1  English           Kids          7.4
# 492                        1  English           Kids          7.4
# 339                        1  English         Comedy          7.4
#
#     Age of viewers
# 20             16+
# 452            All
# 1              16+
# 17             18+
# 73             18+
# 0              18+
# 19             18+
# 493            All
# 492            All
# 339            18+
